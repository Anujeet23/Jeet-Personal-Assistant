# %%
import pyttsx3
import speech_recognition as sr
import webbrowser
import openai
from IPython.display import Audio
import datetime
import os
import random

def ai(prompt):
    openai.api_key = "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"
    text = f"OpenAI response for prompt: {prompt}\n *******************\n\n"
    
    
    response = openai.Completion.create(
      model="text-davinci-003",
      prompt = prompt,
      temperature=0.8,
      max_tokens=256,
      top_p=1,
      frequency_penalty=0,
      presence_penalty=0
    )

    generated_text = response["choices"][0]["text"]
    print(generated_text)
    text += generated_text
    if not os.path.exists("Openai"):
        os.mkdir("Openai")
    
    with open(f"Openai/prompt-{random.randint(1,2343434)}.txt", "w") as f:
        f.write(text)

def say(text):
    text_to_speech.say(text)
    text_to_speech.runAndWait()

def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
       #r.pause_threshold = 0.6
        audio = r.listen(source)
        try:
            print("Recognizing...")
            query = r.recognize_google(audio, language="en-in")
            print(f"User Said: {query}")
            return query
        except Exception as e:
            return "Some Error Occurred. Sorry from Jarvis..."

if __name__ == '__main__':
    text_to_speech = pyttsx3.init()
    say("Hello, I am Jarvis AI created by Anujeet!")
    
    while True:
            print("Listening...")
            query = takeCommand()
            sites = [
                ["youtube","https://www.youtube.com/"],
                ["wikipedia","https://www.wikipedia.org/"],
                ["google","https://www.google.com/"],
                ["github","https://github.com/Anujeet23"],
                ["linkedin","https://www.linkedin.com/in/anujeet-kunturkar/"]
            ]
            for site in sites:
                if f"Open {site[0]}".lower() in query.lower():
                    say(f"Opening {site[0]} sir....")
                    webbrowser.open(site[1])
                    break  # Exit the loop after executing a command
                if "Open Music".lower() in query.lower():
                    audio_file = "Apna-Bana-Le.mp3"
                    display(Audio(audio_file))
                    break  # Exit the loop after executing a command
                if "the time".lower() in query.lower():
                    hour = datetime.datetime.now().strftime("%H")
                    min = datetime.datetime.now().strftime("%M")
                    say(f"Saheb,Atta {hour} ani {min} minutes wajle ahet")
                    break  # Exit the loop after executing a command
                if "Using AI".lower() in query.lower():
                    ai(query)
                    break
# Out:
# Listening...
# Recognizing...
# User Said: write an email to my boss for resignation using a
# Listening...
# Recognizing...
# User Said: write an email to my boss for resignation using air
# bnb
#
# Subject: Resignation from Airbnb
#
# Dear [Boss Name],
#
# I am writing to inform you that I am resigning from my role at Airbnb, effective [date].
#
# I have thoroughly enjoyed my time working at Airbnb and I am grateful for the opportunities I have been given here. I have learnt a lot and have been incredibly well supported since I joined.
#
# I am confident that the team is now in a great position and is well-equipped to move forward without me. I will make sure to wrap up any projects I am currently working on before leaving and I am happy to answer any questions or provide any assistance or training that may be needed.
#
# I wish you and the team all the best for the future.
#
# Sincerely,
#
# [Your Name]
# Listening...
# Recognizing...
# Listening...
# Recognizing...
# ...
